# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('stock_data.csv',skiprows=1)

# %% [markdown]
# skiprows: Line numbers to skip (0-indexed) or number of lines to skip (int) at the start of the file.

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# Alternative: header

# %%
df=pd.read_csv('stock_data.csv',header=1)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv('stock_data.csv',header=1,names=['stock_symbol','eps','revenue','price','people'])

# %%
df
# Out:
#   stock_symbol            eps  revenue price         people
# 0        GOOGL          27.82       87   845     larry page
# 1          WMT           4.61      484    65           n.a.
# 2         MSFT             -1       85    64     bill gates
# 3         RIL   not available       50  1023  mukesh ambani
# 4         TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# names=[...]
#
# Assigns custom column names instead of reading them from the file.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   stock_symbol  5 non-null      str
#  1   eps           5 non-null      str
#  2   revenue       5 non-null      int64
#  3   price         5 non-null      str
#  4   people        5 non-null      str
# dtypes: int64(1), str(4)
# memory usage: 332.0 bytes

# %%
df=pd.read_csv('stock_data.csv',skiprows=1,na_values={'eps':'not available','price':'n.a.','revenue':-1,'people':'n.a.'})

# %% [markdown]
# na_values: treat specific strings as missing values (NaN) in selected columns.

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tickers  5 non-null      str
#  1   eps      4 non-null      float64
#  2   revenue  4 non-null      float64
#  3   price    4 non-null      float64
#  4   people   4 non-null      str
# dtypes: float64(3), str(2)
# memory usage: 332.0 bytes

# %%
df=pd.read_csv('stock_data.csv',header=1,na_values=['not available',-1,'n.a.'])

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df['pe'] = df['price']/df['eps']

# %%
df['pe']
# Out:
# 0    30.373832
# 1    14.099783
# 2          NaN
# 3          NaN
# 4          NaN
# Name: pe, dtype: float64

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people', 'pe'], dtype='str')

# %%
df.to_csv("pe_ratio.csv", index=False, header=False) # export to csv

# %%
# read excel file

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
# Read a specific sheet by name
df_movies = pd.read_excel('movies_db.xlsx','movies')

# %%
df_movies.head()
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5
# 3          2017          7.9  Marvel Studios            5
# 4          2022          6.8  Marvel Studios            5

# %%
df_financials = pd.read_excel('movies_db.xlsx','financials')

# %%
df_financials.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions       $$
# 3       104   180.0    854.0  Millions  Dollars
# 4       105   250.0    670.0  Millions      USD

# %%
df_financials['currency'].unique()
# Out:
# <StringArray>
# ['INR', 'USD', '$$', 'Dollars']
# Length: 4, dtype: str

# %%
df_financials['currency'] = df_financials['currency'].replace({'$$':'USD','Dollars':'USD'})

# %%
df_financials['currency'].unique()
# Out:
# <StringArray>
# ['INR', 'USD']
# Length: 2, dtype: str

# %%
df_financials.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD
# 3       104   180.0    854.0  Millions      USD
# 4       105   250.0    670.0  Millions      USD

# %%
df_merged = pd.merge(df_movies, df_financials, on='movie_id')

# %%
df_merged.head()
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating          studio  language_id  budget  revenue  \
# 0          2022          8.4   Hombale Films            3     1.0     12.5
# 1          2022          7.0  Marvel Studios            5   200.0    954.8
# 2          2013          6.8  Marvel Studios            5   165.0    644.8
# 3          2017          7.9  Marvel Studios            5   180.0    854.0
# 4          2022          6.8  Marvel Studios            5   250.0    670.0
#
#        unit currency
# 0  Billions      INR
# 1  Millions      USD
# 2  Millions      USD
# ...

# %% [markdown]
# This way we can merge 2 different dataframes based on a common column.

# %%
df = pd.DataFrame({'student_id':[1,2,3],
'name':['Joy','Zim','Duke']})

# %%
df
# Out:
#    student_id  name
# 0           1   Joy
# 1           2   Zim
# 2           3  Duke
