# %%
# import necessary library
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('movies.csv')

# %%
# return 1st 5 rows
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
# return any 5 rows
df.sample(5)
# Out:
#                                  title   industry  release_year  imdb_rating  \
# 12                       The Godfather  Hollywood          1972          9.2
# 19  Captain America: The First Avenger  Hollywood          2011          6.9
# 9                              Titanic  Hollywood          1997          7.9
# 17                   Avengers: Endgame  Hollywood          2019          8.4
# 33                    K.G.F: Chapter 2  Bollywood          2022          8.4
#
#                 studio  budget  revenue      unit currency language
# 12  Paramount Pictures     7.2    291.0  Millions      USD  English
# 19      Marvel Studios   216.7    370.6  Millions      USD  English
# 9   Paramount Pictures   200.0   2202.0  Millions      USD  English
# 17      Marvel Studios   400.0   2798.0  Millions      USD  English
# 33       Hombale Films     1.0     12.5  Billions      INR  Kannada

# %%
# return the last n rows of a DataFrame
df.tail(5)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
# check the dimensionality of the DataFrame
df.shape
# Out:
# (37, 10)

# %% [markdown]
# total 37 rows and 10 columns

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='str')

# %%
df.industry.unique()
# Out:
# <StringArray>
# ['Bollywood', 'Hollywood']
# Length: 2, dtype: str

# %% [markdown]
# movies are from 2 unique industry

# %%
df.language.unique()
# Out:
# <StringArray>
# ['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu']
# Length: 5, dtype: str

# %%
df['language'].unique()
# Out:
# <StringArray>
# ['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu']
# Length: 5, dtype: str

# %%
df['language'].nunique()
# Out:
# 5

# %%
df['industry'].value_counts() # count the frequency of each unique value in the industry column
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df['language'].value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df[['title','industry','imdb_rating']]
# Out:
#                                           title   industry  imdb_rating
# 0                               Pather Panchali  Bollywood          8.3
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          7.0
# 2                         Thor: The Dark World   Hollywood          6.8
# 3                               Thor: Ragnarok   Hollywood          7.9
# 4                       Thor: Love and Thunder   Hollywood          6.8
# 5                      The Shawshank Redemption  Hollywood          9.3
# 6                                  Interstellar  Hollywood          8.6
# 7                      The Pursuit of Happyness  Hollywood          8.0
# 8                                     Gladiator  Hollywood          8.5
# 9                                       Titanic  Hollywood          7.9
# 10                        It's a Wonderful Life  Hollywood          8.6
# 11                                       Avatar  Hollywood          7.8
# ...

# %%
df[(df.release_year <= 2010) & (df.release_year >= 2000)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %%
df[df.studio == 'Marvel Studios'] # returns all rows where studio is "Marvel Studios".
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
# generate descriptive statistics
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
# get a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     str
#  1   industry      37 non-null     str
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     str
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     str
#  8   currency      37 non-null     str
#  9   language      37 non-null     str
# dtypes: float64(3), int64(1), str(6)
# memory usage: 3.0 KB

# %%
# find maximum imdb rating
df.imdb_rating.max()
# Out:
# np.float64(9.3)

# %%
# find minimum imdb rating
df.imdb_rating.min()
# Out:
# np.float64(1.9)

# %%
df['release_year'].apply(lambda x:2023-x)
# Out:
# 0     68
# 1      1
# 2     10
# 3      6
# 4      1
# 5     29
# 6      9
# 7     17
# 8     23
# 9     26
# 10    77
# 11    14
# 12    51
# 13    15
# 14    30
# 15    30
# 16     4
# 17     4
# 18     5
# 19    12
# 20     9
# 21    28
# 22    14
# 23    22
# 24     8
# 25    16
# 26    20
# 27     9
# 28     5
# 29     1
# 30     8
# 31     5
# 32     2
# 33     1
# 34     2
# 35     1
# 36     8
# Name: release_year, dtype: int64

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
df['profit']
# Out:
# 0     30000.00
# 1       754.80
# 2       479.80
# 3       674.00
# 4       420.00
# 5        48.30
# 6       536.80
# 7       252.10
# 8       357.50
# 9      2002.00
# 10        0.12
# 11     2610.00
# 12      283.80
# 13      821.00
# 14      300.20
# 15      983.00
# 16      247.60
# 17     2398.00
# 18     1648.00
# 19      153.90
# 20      537.40
# 21     1600.00
# 22     3450.00
# 23      970.00
# 24        2.10
# 25     1230.00
# 26      310.00
# 27     7690.00
# 28        4.90
# 29     3159.00
# 30    10790.00
# 31        1.30
# 32      450.00
# 33       11.50
# 34        1.60
# 35        6.50
# 36        4.70
# Name: profit, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index('title',inplace=True)

# %%
df.head()
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
# Thor: Love and Thunder                               6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# ...

# %%
df.loc['Pather Panchali']
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# profit                            30000.0
# Name: Pather Panchali, dtype: object

# %%
df.loc[['Pather Panchali', 'Doctor Strange in the Multiverse of Madness']]
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# Pather Panchali                              70000.0  100000.0  Thousands
# Doctor Strange in the Multiverse of Madness    200.0     954.8   Millions
#
#                                             currency language   profit
# title
# ...

# %%
df.iloc[0]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# profit                            30000.0
# Name: Pather Panchali, dtype: object

# %% [markdown]
# In Pandas, both .loc and .iloc are used for selecting subsets of data from a DataFrame.

# %% [markdown]
# loc → Label-based indexing .iloc → Integer position-based indexing

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language   profit
# 0      INR  Bengali  30000.0
# 1      USD  English    754.8
# ...

# %%
df.iloc[2:5]
# Out:
#                      title   industry  release_year  imdb_rating  \
# 2    Thor: The Dark World   Hollywood          2013          6.8
# 3          Thor: Ragnarok   Hollywood          2017          7.9
# 4  Thor: Love and Thunder   Hollywood          2022          6.8
#
#            studio  budget  revenue      unit currency language  profit
# 2  Marvel Studios   165.0    644.8  Millions      USD  English   479.8
# 3  Marvel Studios   180.0    854.0  Millions      USD  English   674.0
# 4  Marvel Studios   250.0    670.0  Millions      USD  English   420.0
